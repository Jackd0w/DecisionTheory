# %%
import numpy as np
import pandas as pd

# %%
data = {"Название":["СПбГЭТУ «ЛЭТИ»", "РХТУ им. Д. И. Менделеева", "СЗИУ РАНХиГС", "УрФУ", "НИТУ «МИСиС»", "МГТУ им. Баумана", "КФУ", "СФУ",
                    "НИУ ВШЭ", "РТУ МИРЭА"], 
        "Баллы ЕГЭ, бюджет, min":[10, 10, 15, 10, 15, 10, 10, 5, 15, 10], 
        "Количество бюджетных мест, max":[5, 5, 5, 15, 15, 15, 15, 15, 10, 15],
        "Баллы ЕГЭ, платное, min":[10, 5, 15, 10, 15, 5, 5, 5, 15, 5], 
        "Количество платных мест, max":[10, 5, 10, 10, 10, 10, 5, 5, 15, 15],
        "Отзывы студентов, в 10-ти балной шкале, max":[5, 10, 2, 2, 10, 10, 5, 5, 5, 10], 
        "Количесво образовательных программ, max":[3, 3, 3, 8, 5, 5, 8, 8, 3, 3]
    }
    
df = pd.DataFrame(data=data)

# %%
df
# Out:
#                     Название  Баллы ЕГЭ, бюджет, min  \
# 0             СПбГЭТУ «ЛЭТИ»                      10
# 1  РХТУ им. Д. И. Менделеева                      10
# 2               СЗИУ РАНХиГС                      15
# 3                       УрФУ                      10
# 4               НИТУ «МИСиС»                      15
# 5           МГТУ им. Баумана                      10
# 6                        КФУ                      10
# 7                        СФУ                       5
# 8                    НИУ ВШЭ                      15
# 9                  РТУ МИРЭА                      10
#
#    Количество бюджетных мест, max  Баллы ЕГЭ, платное, min  \
# 0                               5                       10
# 1                               5                        5
# 2                               5                       15
# 3                              15                       10
# 4                              15                       15
# 5                              15                        5
# 6                              15                        5
# 7                              15                        5
# 8                              10                       15
# 9                              15                        5
#
#    Количество платных мест, max  Отзывы студентов, в 10-ти балной шкале, max  \
# 0                            10                                            5
# 1                             5                                           10
# 2                            10                                            2
# 3                            10                                            2
# 4                            10                                           10
# 5                            10                                           10
# 6                             5                                            5
# 7                             5                                            5
# 8                            15                                            5
# 9                            15                                           10
#
#    Количесво образовательных программ, max
# 0                                        3
# 1                                        3
# 2                                        3
# 3                                        8
# 4                                        5
# 5                                        5
# 6                                        8
# 7                                        8
# 8                                        3
# 9                                        3

# %%
string = list(data.keys())


w, h = 10, 10
new_data = [['-' for x in range(w)] for y in range(h)]
for i in range(w):
    new_data[i][i] = 'X'

# %%
def pareto_search(j):
    str_input = string[j]
    print("Критерий: {0}".format(str_input))
    P = 0
    N = 0
    if str_input == "Баллы ЕГЭ, бюджет, min":
        if data[str_input][i] < data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i))
            P += 5
            j += 1
        elif data[str_input][i] > data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i + 1))
            N += 5
            j += 1
        elif data[str_input][i] == data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вузы №{0} и №{1} равны".format(i, i + 1))
            j += 1

    elif str_input == "Баллы ЕГЭ, платное, min":
        if data[str_input][i] < data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i))
            P += 4
            j += 1
        elif data[str_input][i] > data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i + 1))
            N += 4
            j += 1
        elif data[str_input][i] == data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вузы №{0} и №{1} равны".format(i, i + 1))
            j += 1
                
    elif str_input == "Количество бюджетных мест, max":
        if data[str_input][i] > data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i))
            P += 5
            j += 1
                
        elif data[str_input][i] < data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i + 1))
            N += 5
            j += 1

        elif data[str_input][i] == data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вузы №{0} и №{1} равны".format(i, i + 1))
            j += 1

    elif str_input == "Количество платных мест, max":
        if data[str_input][i] > data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i))
            P += 4
            j += 1
                
        elif data[str_input][i] < data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i + 1))
            N += 4
            j += 1

        elif data[str_input][i] == data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вузы №{0} и №{1} равны".format(i, i + 1))
            j += 1
    elif data[str_input][i] == data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вузы №{0} и №{1} равны".format(i, i + 1))
            j += 1
                
    elif str_input == "Количество бюджетных мест, max":
        if data[str_input][i] > data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i))
            P += 5
            j += 1
                
        elif data[str_input][i] < data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i + 1))
            N += 5
            j += 1

        elif data[str_input][i] == data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вузы №{0} и №{1} равны".format(i, i + 1))
            j += 1

    elif str_input == "Количество платных мест, max":
        if data[str_input][i] > data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i))
            P += 4
            j += 1
                
        elif data[str_input][i] < data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вуз №{0} лучше".format(i + 1))
            N += 4
            j += 1

        elif data[str_input][i] == data[str_input][i+1]:
            print("Сравниваем вузы №{0} и №{1}".format(i, i + 1))
            print("В этом критерии вузы №{0} и №{1} равны".format(i, i + 1))
            j += 1
    return (P, N)

# %%
P_sum = 0
N_sum = 0

for i in range(0, 9):
   
    for j in range(1, 7):
        res = pareto_search(j)
        P_sum += res[0]
        N_sum += res[1]
        print(P_sum, N_sum)
    try:
        D = P_sum / N_sum
    except ZeroDivisionError:
        D = 'inf'
    print(D)
        
    if D < 1:
        print("Принимаем вуз номер{0}".format(i+1))
        try:
            n_D = 1/D
            print(n_D)
        except ZeroDivisionError:
            n_D = 'inf'
            new_data[i+1][i] = n_D
            new_data[i][i+1] = '-'
    elif D > 1:
        print("Принимаем вуз номер{0}".format(i))
        print(D)
        new_data[i+1][i] = D
        new_data[i+1][i] = '-'
# Out:
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №0 и №1
# В этом критерии вузы №0 и №1 равны
# 0 0
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №0 и №1
# В этом критерии вузы №0 и №1 равны
# 0 0
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №0 и №1
# В этом критерии вуз №1 лучше
# 0 4
# Критерий: Количество платных мест, max
# Сравниваем вузы №0 и №1
# В этом критерии вуз №0 лучше
# 4 4
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# 4 4
# Критерий: Количесво образовательных программ, max
# Сравниваем вузы №0 и №1
# В этом критерии вузы №0 и №1 равны
# 4 4
# 1.0
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №1 и №2
# В этом критерии вуз №1 лучше
# 9 4
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №1 и №2
# В этом критерии вузы №1 и №2 равны
# 9 4
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №1 и №2
# В этом критерии вуз №1 лучше
# 13 4
# Критерий: Количество платных мест, max
# Сравниваем вузы №1 и №2
# В этом критерии вуз №2 лучше
# 13 8
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# 13 8
# Критерий: Количесво образовательных программ, max
# Сравниваем вузы №1 и №2
# В этом критерии вузы №1 и №2 равны
# 13 8
# 1.625
# Принимаем вуз номер1
# 1.625
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №2 и №3
# В этом критерии вуз №3 лучше
# 13 13
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №2 и №3
# В этом критерии вуз №3 лучше
# 13 18
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №2 и №3
# В этом критерии вуз №3 лучше
# 13 22
# Критерий: Количество платных мест, max
# Сравниваем вузы №2 и №3
# В этом критерии вузы №2 и №3 равны
# 13 22
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# Сравниваем вузы №2 и №3
# В этом критерии вузы №2 и №3 равны
# 13 22
# Критерий: Количесво образовательных программ, max
# 13 22
# 0.5909090909090909
# Принимаем вуз номер3
# 1.6923076923076923
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №3 и №4
# В этом критерии вуз №3 лучше
# 18 22
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №3 и №4
# В этом критерии вузы №3 и №4 равны
# 18 22
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №3 и №4
# В этом критерии вуз №3 лучше
# 22 22
# Критерий: Количество платных мест, max
# Сравниваем вузы №3 и №4
# В этом критерии вузы №3 и №4 равны
# 22 22
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# 22 22
# Критерий: Количесво образовательных программ, max
# 22 22
# 1.0
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №4 и №5
# В этом критерии вуз №5 лучше
# 22 27
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №4 и №5
# В этом критерии вузы №4 и №5 равны
# 22 27
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №4 и №5
# В этом критерии вуз №5 лучше
# 22 31
# Критерий: Количество платных мест, max
# Сравниваем вузы №4 и №5
# В этом критерии вузы №4 и №5 равны
# 22 31
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# Сравниваем вузы №4 и №5
# В этом критерии вузы №4 и №5 равны
# 22 31
# Критерий: Количесво образовательных программ, max
# Сравниваем вузы №4 и №5
# В этом критерии вузы №4 и №5 равны
# 22 31
# 0.7096774193548387
# Принимаем вуз номер5
# 1.409090909090909
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №5 и №6
# В этом критерии вузы №5 и №6 равны
# 22 31
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №5 и №6
# В этом критерии вузы №5 и №6 равны
# 22 31
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №5 и №6
# В этом критерии вузы №5 и №6 равны
# 22 31
# Критерий: Количество платных мест, max
# Сравниваем вузы №5 и №6
# В этом критерии вуз №5 лучше
# 26 31
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# 26 31
# Критерий: Количесво образовательных программ, max
# 26 31
# 0.8387096774193549
# Принимаем вуз номер6
# 1.1923076923076923
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №6 и №7
# В этом критерии вуз №7 лучше
# 26 36
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №6 и №7
# В этом критерии вузы №6 и №7 равны
# 26 36
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №6 и №7
# В этом критерии вузы №6 и №7 равны
# 26 36
# Критерий: Количество платных мест, max
# Сравниваем вузы №6 и №7
# В этом критерии вузы №6 и №7 равны
# 26 36
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# Сравниваем вузы №6 и №7
# В этом критерии вузы №6 и №7 равны
# 26 36
# Критерий: Количесво образовательных программ, max
# Сравниваем вузы №6 и №7
# В этом критерии вузы №6 и №7 равны
# 26 36
# 0.7222222222222222
# Принимаем вуз номер7
# 1.3846153846153846
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №7 и №8
# В этом критерии вуз №7 лучше
# 31 36
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №7 и №8
# В этом критерии вуз №7 лучше
# 36 36
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №7 и №8
# В этом критерии вуз №7 лучше
# 40 36
# Критерий: Количество платных мест, max
# Сравниваем вузы №7 и №8
# В этом критерии вуз №8 лучше
# 40 40
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# Сравниваем вузы №7 и №8
# В этом критерии вузы №7 и №8 равны
# 40 40
# Критерий: Количесво образовательных программ, max
# 40 40
# 1.0
# Критерий: Баллы ЕГЭ, бюджет, min
# Сравниваем вузы №8 и №9
# В этом критерии вуз №9 лучше
# 40 45
# Критерий: Количество бюджетных мест, max
# Сравниваем вузы №8 и №9
# В этом критерии вуз №9 лучше
# 40 50
# Критерий: Баллы ЕГЭ, платное, min
# Сравниваем вузы №8 и №9
# В этом критерии вуз №9 лучше
# 40 54
# Критерий: Количество платных мест, max
# Сравниваем вузы №8 и №9
# В этом критерии вузы №8 и №9 равны
# 40 54
# Критерий: Отзывы студентов, в 10-ти балной шкале, max
# 40 54
# Критерий: Количесво образовательных программ, max
# Сравниваем вузы №8 и №9
# В этом критерии вузы №8 и №9 равны
# 40 54
# 0.7407407407407407
# Принимаем вуз номер9
# 1.35
